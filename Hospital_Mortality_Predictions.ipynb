# %%
import pandas as pd
import numpy as np
df = pd.read_csv('data01.csv')
df.head()
# Out:
#    group      ID  outcome  age  gendera        BMI  hypertensive  \
# 0      1  125047      0.0   72        1  37.588179             0
# 1      1  139812      0.0   75        2        NaN             0
# 2      1  109787      0.0   83        2  26.572634             0
# 3      1  130587      0.0   43        2  83.264629             0
# 4      1  138290      0.0   75        2  31.824842             1
#
#    atrialfibrillation  CHD with no MI  diabetes  ...  Blood sodium  \
# 0                   0               0         1  ...    138.750000
# 1                   0               0         0  ...    138.888889
# 2                   0               0         0  ...    140.714286
# 3                   0               0         0  ...    138.500000
# 4                   0               0         0  ...    136.666667
#
#    Blood calcium    Chloride  Anion gap  Magnesium ion     PH  Bicarbonate  \
# 0       7.463636  109.166667  13.166667       2.618182  7.230    21.166667
# ...

# %%
df.shape
# Out:
# (1177, 51)

# %%
df.isnull().sum()
# Out:
# group                         0
# ID                            0
# outcome                       1
# age                           0
# gendera                       0
# BMI                         215
# hypertensive                  0
# atrialfibrillation            0
# CHD with no MI                0
# diabetes                      0
# deficiencyanemias             0
# depression                    0
# Hyperlipemia                  0
# Renal failure                 0
# COPD                          0
# heart rate                   13
# Systolic blood pressure      16
# Diastolic blood pressure     16
# Respiratory rate             13
# temperature                  19
# SP O2                        13
# Urine output                 36
# hematocrit                    0
# RBC                           0
# MCH                           0
# MCHC                          0
# MCV                           0
# RDW                           0
# Leucocyte                     0
# ...

# %%
df.columns
# Out:
# Index(['group', 'ID', 'outcome', 'age', 'gendera', 'BMI', 'hypertensive',
#        'atrialfibrillation', 'CHD with no MI', 'diabetes', 'deficiencyanemias',
#        'depression', 'Hyperlipemia', 'Renal failure', 'COPD', 'heart rate',
#        'Systolic blood pressure', 'Diastolic blood pressure',
#        'Respiratory rate', 'temperature', 'SP O2', 'Urine output',
#        'hematocrit', 'RBC', 'MCH', 'MCHC', 'MCV', 'RDW', 'Leucocyte',
#        'Platelets', 'Neutrophils', 'Basophils', 'Lymphocyte', 'PT', 'INR',
#        'NT-proBNP', 'Creatine kinase', 'Creatinine', 'Urea nitrogen',
#        'glucose', 'Blood potassium', 'Blood sodium', 'Blood calcium',
#        'Chloride', 'Anion gap', 'Magnesium ion', 'PH', 'Bicarbonate',
#        'Lactic acid', 'PCO2', 'EF'],
#       dtype='object')

# %%
df = df.drop(['group','ID'],axis = 1)

# %%
df.dtypes
# Out:
# outcome                     float64
# age                           int64
# gendera                       int64
# BMI                         float64
# hypertensive                  int64
# atrialfibrillation            int64
# CHD with no MI                int64
# diabetes                      int64
# deficiencyanemias             int64
# depression                    int64
# Hyperlipemia                  int64
# Renal failure                 int64
# COPD                          int64
# heart rate                  float64
# Systolic blood pressure     float64
# Diastolic blood pressure    float64
# Respiratory rate            float64
# temperature                 float64
# SP O2                       float64
# Urine output                float64
# hematocrit                  float64
# RBC                         float64
# MCH                         float64
# MCHC                        float64
# MCV                         float64
# RDW                         float64
# ...

# %%
df.head()
# Out:
#    outcome  age  gendera        BMI  hypertensive  atrialfibrillation  \
# 0      0.0   72        1  37.588179             0                   0
# 1      0.0   75        2        NaN             0                   0
# 2      0.0   83        2  26.572634             0                   0
# 3      0.0   43        2  83.264629             0                   0
# 4      0.0   75        2  31.824842             1                   0
#
#    CHD with no MI  diabetes  deficiencyanemias  depression  ...  Blood sodium  \
# 0               0         1                  1           0  ...    138.750000
# 1               0         0                  1           0  ...    138.888889
# 2               0         0                  1           0  ...    140.714286
# 3               0         0                  0           0  ...    138.500000
# 4               0         0                  1           0  ...    136.666667
#
# ...

# %%
df["BMI"].fillna(df["BMI"].mean(),inplace = True)

# %%
df['heart rate'].fillna(df["heart rate"].mean(),inplace = True)
df['Systolic blood pressure'].fillna(df['Systolic blood pressure'].mean(), inplace = True)
df['Diastolic blood pressure'].fillna(df['Diastolic blood pressure'].mean(), inplace = True)
df['Respiratory rate'].fillna(df['Respiratory rate'].mean(),inplace= True)
df['temperature'].fillna(df['temperature'].mean(),inplace= True)
df['SP O2'].fillna(df['SP O2'].mean(),inplace= True)
df['Urine output'].fillna(df['Urine output'].mean(),inplace= True)
df['Neutrophils'].fillna(df['Neutrophils'].mean(),inplace= True)
df['Basophils'].fillna(df['Basophils'].mean(),inplace= True)
df['Lymphocyte'].fillna(df['Lymphocyte'].mean(),inplace= True)
df['PT'].fillna(df['PT'].mean(),inplace= True)
df['Creatine kinase'].fillna(df['Creatine kinase'].mean(),inplace= True)
df['glucose'].fillna(df['glucose'].mean(),inplace= True)
df['PH'].fillna(df['PH'].mean(),inplace= True)
df['Lactic acid'].fillna(df['Lactic acid'].mean(),inplace= True)
df['PCO2'].fillna(df['PCO2'].mean(),inplace= True)

# %%
df = df.dropna(how = "any")

# %%
df.head()
# Out:
#    outcome  age  gendera        BMI  hypertensive  atrialfibrillation  \
# 0      0.0   72        1  37.588179             0                   0
# 2      0.0   83        2  26.572634             0                   0
# 3      0.0   43        2  83.264629             0                   0
# 5      0.0   76        1  24.262293             1                   1
# 6      0.0   72        1  39.667426             1                   0
#
#    CHD with no MI  diabetes  deficiencyanemias  depression  ...  Blood sodium  \
# 0               0         1                  1           0  ...    138.750000
# 2               0         0                  1           0  ...    140.714286
# 3               0         0                  0           0  ...    138.500000
# 5               0         0                  1           0  ...    136.250000
# 6               0         0                  0           0  ...    144.133333
#
# ...

# %%
df.isnull().sum()
# Out:
# outcome                     0
# age                         0
# gendera                     0
# BMI                         0
# hypertensive                0
# atrialfibrillation          0
# CHD with no MI              0
# diabetes                    0
# deficiencyanemias           0
# depression                  0
# Hyperlipemia                0
# Renal failure               0
# COPD                        0
# heart rate                  0
# Systolic blood pressure     0
# Diastolic blood pressure    0
# Respiratory rate            0
# temperature                 0
# SP O2                       0
# Urine output                0
# hematocrit                  0
# RBC                         0
# MCH                         0
# MCHC                        0
# MCV                         0
# RDW                         0
# Leucocyte                   0
# Platelets                   0
# Neutrophils                 0
# Basophils                   0
# Lymphocyte                  0
# ...

# %%
df.corr()
# Out:
#                            outcome       age   gendera       BMI  \
# outcome                   1.000000  0.063090 -0.021054 -0.054130
# age                       0.063090  1.000000  0.080560 -0.355846
# gendera                  -0.021054  0.080560  1.000000  0.024398
# BMI                      -0.054130 -0.355846  0.024398  1.000000
# hypertensive             -0.071102  0.182631  0.006005 -0.031002
# atrialfibrillation        0.096354  0.289387 -0.034436 -0.105093
# CHD with no MI           -0.013886  0.036402 -0.075039 -0.059401
# diabetes                 -0.054184 -0.096166 -0.032868  0.143816
# deficiencyanemias        -0.099767  0.014178  0.077304 -0.021173
# depression               -0.062928 -0.097425  0.081305  0.022465
# Hyperlipemia             -0.059428  0.115687 -0.034506 -0.016682
# Renal failure            -0.107796  0.112260 -0.092296 -0.042849
# COPD                     -0.045728 -0.007325 -0.074449  0.011129
# ...

# %%
df.describe()
# Out:
#            outcome          age      gendera          BMI  hypertensive  \
# count  1155.000000  1155.000000  1155.000000  1155.000000   1155.000000
# mean      0.136797    74.100433     1.526407    30.202474      0.719481
# std       0.343781    13.349727     0.499518     8.483261      0.449448
# min       0.000000    19.000000     1.000000    13.346801      0.000000
# 25%       0.000000    65.000000     1.000000    25.265587      0.000000
# 50%       0.000000    77.000000     2.000000    30.188278      1.000000
# 75%       0.000000    85.000000     2.000000    32.119633      1.000000
# max       1.000000    99.000000     2.000000   104.970366      1.000000
#
#        atrialfibrillation  CHD with no MI     diabetes  deficiencyanemias  \
# count         1155.000000     1155.000000  1155.000000        1155.000000
# mean             0.455411        0.085714     0.421645           0.340260
# std              0.498224        0.280063     0.494036           0.474002
# ...

# %%
df.hist(figsize = (15,15))
# Out:
# array([[<Axes: title={'center': 'outcome'}>,
#         <Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'gendera'}>,
#         <Axes: title={'center': 'BMI'}>,
#         <Axes: title={'center': 'hypertensive'}>,
#         <Axes: title={'center': 'atrialfibrillation'}>,
#         <Axes: title={'center': 'CHD with no MI'}>],
#        [<Axes: title={'center': 'diabetes'}>,
#         <Axes: title={'center': 'deficiencyanemias'}>,
#         <Axes: title={'center': 'depression'}>,
#         <Axes: title={'center': 'Hyperlipemia'}>,
#         <Axes: title={'center': 'Renal failure'}>,
#         <Axes: title={'center': 'COPD'}>,
#         <Axes: title={'center': 'heart rate'}>],
#        [<Axes: title={'center': 'Systolic blood pressure'}>,
#         <Axes: title={'center': 'Diastolic blood pressure'}>,
#         <Axes: title={'center': 'Respiratory rate'}>,
#         <Axes: title={'center': 'temperature'}>,
#         <Axes: title={'center': 'SP O2'}>,
# ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
for i,predict in enumerate(df):
  plt.figure(i)
  sns.countplot(data = df, x= predict, hue = "outcome")
# Out:
# <ipython-input-17-3f26e2a721e6>:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(i)

# %%
Y = df.iloc[:,0:1]
X = df.iloc[:,2:]

# %%
X
# Out:
#       gendera        BMI  hypertensive  atrialfibrillation  CHD with no MI  \
# 0           1  37.588179             0                   0               0
# 2           2  26.572634             0                   0               0
# 3           2  83.264629             0                   0               0
# 5           1  24.262293             1                   1               0
# 6           1  39.667426             1                   0               0
# ...       ...        ...           ...                 ...             ...
# 1172        1  25.516870             1                   1               0
# 1173        1  25.822710             0                   1               0
# 1174        2  23.891779             1                   1               0
# 1175        2  35.288554             0                   0               1
# 1176        1  23.121384             1                   0               0
#
# ...

# %%
Y
# Out:
#       outcome
# 0         0.0
# 2         0.0
# 3         0.0
# 5         0.0
# 6         0.0
# ...       ...
# 1172      0.0
# 1173      0.0
# 1174      0.0
# 1175      0.0
# 1176      0.0
#
# [1155 rows x 1 columns]

# %%
#Feature Extraction
from numpy.core.arrayprint import set_printoptions
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection  import chi2
#Feature Extraction
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import mutual_info_classif
test1 = SelectKBest(score_func = mutual_info_classif, k = 10)
test = SelectKBest(score_func=f_classif, k = 10)
set_printoptions(precision = 3)
f = test1.fit(X,Y)
fit = test.fit(X,Y)
print(fit.scores_)
print(f.scores_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [ 0.511  3.388  5.859 10.805  0.222  3.395 11.592  4.584  4.086 13.555
#   2.416 19.279 19.674  9.25  15.062  9.162  6.351 34.773  0.394  0.648
#   0.113  1.143  1.021 25.832 52.583  8.591  5.532  0.648 20.554 23.157
#  24.577 16.387  5.937  2.592 50.238  1.118 23.216  4.402 40.333  5.061
#  65.88   6.293 25.484 62.152 54.546  2.222  0.629]
# [0.009 0.    0.    0.015 0.    0.008 0.008 0.    0.013 0.    0.    0.018
#  0.    0.    0.003 0.015 0.007 0.016 0.    0.004 0.004 0.008 0.    0.02
#  0.027 0.001 0.006 0.005 0.034 0.038 0.014 0.    0.007 0.013 0.017 0.01
#  0.007 0.016 0.01  0.    0.022 0.    0.035 0.029 0.02  0.013 0.   ]
# ...

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
rfe = RFE(model, n_features_to_select =15, step =1)
feature = rfe.fit(X,Y)
feature.n_features_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...

# %%
feature.support_
# Out:
# array([False, False,  True,  True, False,  True,  True,  True, False,
#         True,  True, False, False, False, False, False, False, False,
#        False,  True, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#         True, False,  True, False,  True,  True, False, False,  True,
#        False, False])

# %%
feature.ranking_
# Out:
# array([26, 20,  1,  1, 30,  1,  1,  1,  2,  1,  1, 14, 25, 13,  8,  9,  7,
#        31, 15,  1, 16, 22, 11,  1,  6, 21, 23, 17, 12, 18,  3, 33, 32,  1,
#        10, 28,  1, 19,  1, 27,  1,  1, 29,  4,  1,  5, 24])

# %%
#Feature Importance using DecisionTree
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X,Y)
print(model.feature_importances_)
# Out:
# [0.005 0.016 0.006 0.    0.007 0.    0.004 0.    0.    0.043 0.    0.013
#  0.008 0.    0.016 0.03  0.033 0.018 0.017 0.026 0.02  0.021 0.    0.002
#  0.028 0.075 0.019 0.019 0.024 0.006 0.019 0.021 0.007 0.043 0.025 0.029
#  0.065 0.039 0.031 0.002 0.086 0.027 0.04  0.03  0.04  0.037 0.   ]

# %%
X
# Out:
#       gendera        BMI  hypertensive  atrialfibrillation  CHD with no MI  \
# 0           1  37.588179             0                   0               0
# 2           2  26.572634             0                   0               0
# 3           2  83.264629             0                   0               0
# 5           1  24.262293             1                   1               0
# 6           1  39.667426             1                   0               0
# ...       ...        ...           ...                 ...             ...
# 1172        1  25.516870             1                   1               0
# 1173        1  25.822710             0                   1               0
# 1174        2  23.891779             1                   1               0
# 1175        2  35.288554             0                   0               1
# 1176        1  23.121384             1                   0               0
#
# ...

# %%
df.dtypes
# Out:
# outcome                     float64
# age                           int64
# gendera                       int64
# BMI                         float64
# hypertensive                  int64
# atrialfibrillation            int64
# CHD with no MI                int64
# diabetes                      int64
# deficiencyanemias             int64
# depression                    int64
# Hyperlipemia                  int64
# Renal failure                 int64
# COPD                          int64
# heart rate                  float64
# Systolic blood pressure     float64
# Diastolic blood pressure    float64
# Respiratory rate            float64
# temperature                 float64
# SP O2                       float64
# Urine output                float64
# hematocrit                  float64
# RBC                         float64
# MCH                         float64
# MCHC                        float64
# MCV                         float64
# RDW                         float64
# ...

# %%
col = ['age','BMI','heart rate',
       'Systolic blood pressure', 'Diastolic blood pressure',
       'Respiratory rate', 'temperature', 'SP O2', 'Urine output',
       'hematocrit', 'RBC', 'MCH', 'MCHC', 'MCV', 'RDW', 'Leucocyte',
       'Platelets', 'Neutrophils', 'Basophils', 'Lymphocyte', 'PT', 'INR',
       'NT-proBNP', 'Creatine kinase', 'Creatinine', 'Urea nitrogen',
       'glucose', 'Blood potassium', 'Blood sodium', 'Blood calcium',
       'Chloride', 'Anion gap', 'Magnesium ion', 'PH', 'Bicarbonate',
       'Lactic acid', 'PCO2', 'EF']
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
df[col] = SS.fit_transform(df[col])
df['gendera'].replace({1:0,2:1},inplace = True)
df
# Out:
#       outcome       age  gendera       BMI  hypertensive  atrialfibrillation  \
# 0         0.0 -0.157407        0  0.870998             0                   0
# 2         0.0  0.666937        0 -0.428068             0                   0
# 3         0.0 -2.330677        0  6.257634             0                   0
# 5         0.0  0.142354        0 -0.700527             1                   1
# 6         0.0 -0.157407        0  1.116204             1                   0
# ...       ...       ...      ...       ...           ...                 ...
# 1172      0.0 -0.906811        0 -0.552574             1                   1
# 1173      0.0  0.292235        0 -0.516507             0                   1
# 1174      0.0  0.816817        0 -0.744222             1                   1
# 1175      0.0  0.367175        0  0.599803             0                   0
# 1176      0.0 -2.030916        0 -0.835075             1                   0
#
# ...

# %%
X = df.iloc[:,1:]
Y = df.iloc[:,0:1]

# %%
Y
# Out:
#       outcome
# 0         0.0
# 2         0.0
# 3         0.0
# 5         0.0
# 6         0.0
# ...       ...
# 1172      0.0
# 1173      0.0
# 1174      0.0
# 1175      0.0
# 1176      0.0
#
# [1155 rows x 1 columns]

# %%
Y.value_counts()
# Out:
# outcome
# 0.0        997
# 1.0        158
# dtype: int64

# %% [markdown]
# Model Building

# %%
from sklearn.model_selection import train_test_split
X1_train,X1_test,Y1_train,Y1_test = train_test_split(X,Y,test_size = 0.3, random_state = 42)

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()
LR.fit(X1_train,Y1_train)
y_predlog = LR.predict(X1_test)
from sklearn.metrics import classification_report
print(classification_report(y_predlog,Y1_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.89      0.94       329
#          1.0       0.29      0.83      0.43        18
#
#     accuracy                           0.88       347
#    macro avg       0.64      0.86      0.68       347
# weighted avg       0.95      0.88      0.91       347
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.model_selection import train_test_split
from imblearn.combine import SMOTEENN
SM = SMOTEENN()
X1,Y1 = SM.fit_resample(X,Y)
X_train,X_test,Y_train,Y_test=train_test_split(X1, Y1,test_size=0.3,random_state = 42)

# %%
print(X_train.shape,X_test.shape,Y_train.shape,Y_test.shape)
# Out:
# (1053, 48) (452, 48) (1053, 1) (452, 1)

# %%
LR.fit(X_train,Y_train)
y_predlog = LR.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(y_predlog,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.87      0.85       144
#          1.0       0.94      0.92      0.93       308
#
#     accuracy                           0.90       452
#    macro avg       0.88      0.89      0.89       452
# weighted avg       0.90      0.90      0.90       452
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.model_selection import StratifiedKFold,cross_val_score
K = StratifiedKFold(n_splits = 10)
result_log = cross_val_score(LR, X,Y, cv=K,n_jobs = -1)
result_log
# Out:
# array([0.862, 0.871, 0.888, 0.845, 0.871, 0.93 , 0.913, 0.878, 0.887,
#        0.87 ])

# %%
result_log
print("Stratified K Fold" ,np.mean(result_log).round(2))
# Out:
# Stratified K Fold 0.88

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier()
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_neighbors' : [1,3,5,7,9,11]
}
Search_KNN = GridSearchCV(KNN, param_grid, cv=5,n_jobs = -1)
res_KNN = Search_KNN.fit(X,Y)
print(Search_KNN.best_params_)
print(Search_KNN.best_score_)
# Out:
# {'n_neighbors': 3}
# 0.8692640692640694
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
KNN = KNeighborsClassifier(n_neighbors=5)
KNN.fit(X_train,Y_train)
y_pred_knn = KNN.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(y_pred_knn,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.99      0.91       128
#          1.0       1.00      0.93      0.96       324
#
#     accuracy                           0.94       452
#    macro avg       0.92      0.96      0.94       452
# weighted avg       0.95      0.94      0.95       452
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
#Model Validation
K = StratifiedKFold(n_splits = 10)
result_KNN = cross_val_score(KNN, X,Y,cv = K)
print(result_KNN)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
print("Stratified for KNN is the ", np.mean(result_KNN).round(2))
# Out:
# Stratified for KNN is the  0.87

# %%
from sklearn.tree import DecisionTreeClassifier
DT = DecisionTreeClassifier()
param_grid = {
    "criterion" : ["gini", "entropy"],
    "splitter" : ["best", "random"],
    "max_depth" : [2,3,5,7,9],
    "min_samples_leaf": [1,2,3,5,7,9],
    "min_samples_split": [2,5,7,9,10]
}
gd_D = GridSearchCV(DT,param_grid,cv= 5, n_jobs = -1)
result_D = gd_D.fit(X,Y)
print(result_D.best_score_)
print(result_D.best_params_)
# Out:
# 0.8744588744588745
# {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 2, 'min_samples_split': 9, 'splitter': 'random'}

# %%
DT = DecisionTreeClassifier(criterion = "gini",splitter = "random", max_depth = 2,min_samples_leaf=1,min_samples_split=2 )
DT.fit(X_train,Y_train)
y_pred = DT.predict(X_test)
print(classification_report(y_pred,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.58      0.55       136
#          1.0       0.81      0.77      0.79       316
#
#     accuracy                           0.71       452
#    macro avg       0.67      0.68      0.67       452
# weighted avg       0.72      0.71      0.72       452

# %% [markdown]
# As we can see that predicting of the 0's and 1's are inconsistent we use the smoteen technique

# %%
from sklearn.model_selection import train_test_split
from imblearn.combine import SMOTEENN
SM = SMOTEENN()
X1,Y1 = SM.fit_resample(X,Y)
Xt_train,Xt_test,Yt_train,Yt_test=train_test_split(X1, Y1,test_size=0.3,random_state = 42)
print(Xt_train.shape,Xt_test.shape,Yt_train.shape,Yt_test.shape)
# Out:
# (1045, 48) (449, 48) (1045, 1) (449, 1)

# %%
from sklearn.tree import DecisionTreeClassifier
DT = DecisionTreeClassifier()
param_grid = {
    "criterion" : ["gini", "entropy"],
    "splitter" : ["best", "random"],
    "max_depth" : [2,3,5,7,9],
    "min_samples_leaf": [1,2,3,5,7,9],
    "min_samples_split": [2,5,7,9,10]
}
gd_D = GridSearchCV(DT,param_grid,cv= 5, n_jobs = -1)
result_D = gd_D.fit(Xt_train,Yt_train)
print(result_D.best_score_)
print(result_D.best_params_)
# Out:
# 0.8717703349282295
# {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'best'}

# %%
DT = DecisionTreeClassifier(criterion = "gini",splitter = "best", max_depth = 9,min_samples_leaf=3,min_samples_split=2 )
DT.fit(Xt_train,Yt_train)
y_pred = DT.predict(Xt_test)
print(classification_report(y_pred,Yt_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.81      0.77       136
#          1.0       0.91      0.87      0.89       313
#
#     accuracy                           0.85       449
#    macro avg       0.82      0.84      0.83       449
# weighted avg       0.86      0.85      0.85       449

# %%
k = StratifiedKFold(n_splits = 10)
result_DT = cross_val_score(DT,X1,Y1,cv = k)
result_DT
# Out:
# array([0.793, 0.813, 0.873, 0.907, 0.859, 0.913, 0.859, 0.886, 0.859,
#        0.886])

# %%
np.mean(result_DT).round(2)
# Out:
# 0.86

# %%
from sklearn.ensemble import RandomForestClassifier
RFF = RandomForestClassifier()
param_grid = {
    "criterion": ["gini", "entropy"],
    'n_estimators': [100,200,300],
    'max_depth' : [2,3,4,5,7,9,11],
    'max_features': ["auto",'sqrt','log2','n_features'],

}

res = GridSearchCV(RFF,param_grid,cv = 5, n_jobs = -1)
res_Rff = res.fit(Xt_train,Yt_train)
print(res_Rff.best_params_)
print(res_Rff.best_score_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 210 fits failed out of a total of 840.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 135 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 340, in fit
#     self._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 600, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
RFF = RandomForestClassifier(criterion = "gini", max_depth = 11, max_features = 'log2', n_estimators = 300)
RFF.fit(Xt_train,Yt_train)
y_predRff = RFF.predict(Xt_test)
print(classification_report(y_predRff,Yt_test))
# Out:
# <ipython-input-124-9dc12ff227a9>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RFF.fit(Xt_train,Yt_train)
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.96      0.92       136
#          1.0       0.98      0.94      0.96       313
#
#     accuracy                           0.95       449
#    macro avg       0.93      0.95      0.94       449
# weighted avg       0.95      0.95      0.95       449

# %%
k= StratifiedKFold(n_splits=10)
result_rff = cross_val_score(RFF, Xt_train,Yt_train, cv = k)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
print(np.mean(result_rff).round(2))
# Out:
# 0.95

# %% [markdown]
# XGBoost Classifier

# %%
import xgboost as xgb
XGB = xgb.XGBClassifier()
param_grid = {
    "learning_rate": [0.1,0.2,0.001,0.002,0.3],
    "gamma" : [0.1,0.2,0.3,0.4,1,2,4,5,10],
    "max_depth": [3,4,5,7,9,11],
    "tree_method": ["auto","exact","approx","hisr"],
    }
resuult = GridSearchCV(XGB,param_grid,cv=5,n_jobs = -1, scoring='accuracy')
result_xb = resuult.fit(Xt_train,Yt_train)
print(result_xb.best_params_)
print(result_xb.best_score_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 1350 fits failed out of a total of 5400.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1350 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/xgboost/core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py", line 1490, in fit
#     self._Booster = train(
# ...

# %%
XGB = xgb.XGBClassifier(gamma = 0.1, learning_rate = 0.3, max_depth = 3, tree_method = 'approx')
XGB.fit(Xt_train,Yt_train)
y_predxgb = XGB.predict(Xt_test)
print(classification_report(y_predxgb,Yt_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.94      0.89       139
#            1       0.97      0.93      0.95       304
#
#     accuracy                           0.93       443
#    macro avg       0.91      0.93      0.92       443
# weighted avg       0.93      0.93      0.93       443

# %%
k = StratifiedKFold(n_splits=10)
result_xgb = cross_val_score(XGB, X1,Y1,cv=k)
print(result_xgb)
print(np.mean(result_xgb).round(2))
# Out:
# [0.912 0.899 0.953 0.959 0.912 0.932 0.959 0.98  0.946 0.98 ]
# 0.94

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import GridSearchCV
BC = BaggingClassifier()
param_grid ={
    'n_estimators' : [200, 300, 400, 500],
    'max_samples' : [0.5, 0.6, 0.7, 0.8],
    'max_features' : [0.5, 0.6, 0.7, 0.8]
}
grid_result  = GridSearchCV(BC,param_grid,cv = 5,n_jobs = -1)
grid_result_BC = grid_result.fit(Xt_train,Yt_train)
print(grid_result_BC.best_params_)
print(grid_result_BC.best_score_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_bagging.py:802: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# {'max_features': 0.6, 'max_samples': 0.8, 'n_estimators': 200}
# 0.9409736879133248

# %%
BC = BaggingClassifier(max_features = 0.6, max_samples = 0.8, n_estimators = 200)
BC.fit(Xt_train,Yt_train)
y_predtest = BC.predict(Xt_test)
print(classification_report(Yt_test,y_predtest))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_bagging.py:802: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.83      0.90       152
#          1.0       0.92      0.99      0.95       291
#
#     accuracy                           0.93       443
#    macro avg       0.95      0.91      0.92       443
# weighted avg       0.94      0.93      0.93       443

# %%
k = StratifiedKFold(n_splits = 10)
result_bag = cross_val_score(BC,Xt_train,Yt_train, cv = k)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_bagging.py:802: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_bagging.py:802: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_bagging.py:802: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
print(result_bag)
print(np.mean(result_bag).round(2))
# Out:
# [0.913 0.942 0.913 0.932 0.942 0.932 0.981 0.942 0.951 0.883]
# 0.93

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
GBC = GradientBoostingClassifier()
param_grid ={
    'n_estimators' : [200, 300, 400, 500],
    'max_features' : ['auto', 'sqrt'],
    'max_depth' : [2, 4, 5, 6],
    'min_samples_split' : [2, 5, 10]
}
grid_result  = GridSearchCV(GBC,param_grid,cv = 5,n_jobs = -1)
grid_result_GBC = grid_result.fit(Xt_train,Yt_train)
print(grid_result_GBC.best_params_)
print(grid_result_GBC.best_score_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# {'max_depth': 6, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 400}
# 0.9535340743867549

# %%
GBC = GradientBoostingClassifier(max_depth = 6, max_features = "sqrt", min_samples_split = 2,n_estimators = 400)
GBC.fit(Xt_train,Yt_train)
y_predGB = GBC.predict(Xt_test)
print(classification_report(Yt_test, y_predGB))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.87      0.91       152
#          1.0       0.93      0.98      0.96       291
#
#     accuracy                           0.94       443
#    macro avg       0.95      0.93      0.94       443
# weighted avg       0.94      0.94      0.94       443

# %%
k = StratifiedKFold(n_splits = 10)
result_GB = cross_val_score(GBC,Xt_train,Yt_train,cv = k)
print(result_GB)
print(np.mean(result_GB).round(2))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
result = {'Algorithm' :['Logistic Regression','KNN Classifier','Decision Tree Classifier','Random Forest Classifier','XGBoost','Bagging Classifier','Gradient Boosting Classifier'],
'Accuracy': [88,87,86,95,94,93,95]}

# %%
Result = pd.DataFrame(result)
Result
# Out:
#                       Algorithm  Accuracy
# 0           Logistic Regression        88
# 1                KNN Classifier        87
# 2      Decision Tree Classifier        86
# 3      Random Forest Classifier        95
# 4                       XGBoost        94
# 5            Bagging Classifier        93
# 6  Gradient Boosting Classifier        95
